# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import fitz  # import PyMuPDF

# %%
def Save_to_csv(pdf_path, csv_save_path):
  carpeta_pdf = pdf_path
  carpeta_csv = csv_save_path

  os.makedirs(carpeta_csv, exist_ok=True)

  archivos_pdf = [archivo for archivo in os.listdir(carpeta_pdf) if archivo.endswith('.pdf')]

  for archivo_pdf in archivos_pdf:
      ruta_completa = os.path.join(carpeta_pdf, archivo_pdf)
      pdf_documento = fitz.open(ruta_completa)
      for i, page in enumerate(pdf_documento):
        tabs = page.find_tables()
        df = []
        for tab in tabs:
          obj = tab.extract()
          for j in obj:
            if( len(j) > 3):
              df.append(j)
        data = pd.DataFrame(df)
        csv_file_path = os.path.join(carpeta_csv, f'{archivo_pdf}_page{i}.csv')
        data.to_csv(csv_file_path, index=False)

# %%
def Export_to_dataframe(pdf_path):
  Final_data = []
  carpeta_pdf = pdf_path
  archivos_pdf = [archivo for archivo in os.listdir(carpeta_pdf) if archivo.endswith('.pdf')]

  for archivo_pdf in archivos_pdf:
      ruta_completa = os.path.join(carpeta_pdf, archivo_pdf)
      pdf_documento = fitz.open(ruta_completa)
      for i, page in enumerate(pdf_documento):
        tabs = page.find_tables()
        df = []
        for tab in tabs:
          obj = tab.extract()
          for j in obj:
            df.append(j)
        Final_data.append(df)

  return Final_data

# %%
def PDF_Scrapper( decision = 'csv', pdf_paths = '/content/drive/MyDrive/Datos PDF/', csv_save_paths = '/content/drive/MyDrive/Datos PDF/CSV/'):
  if( decision == 'csv' ):
    Save_to_csv( pdf_paths, csv_save_paths )
  if( decision == 'df' ):
    return Export_to_dataframe( pdf_paths )

# %%
dl = PDF_Scrapper('df', './tlibs/data')
dl
# Out:
# [[['EQUIPO\nDESCRIPCION\n302468641',
#    'CANTIDAD\nA',
#    'TARIFA\nB',
#    'COSTO HORA\nC=AxB',
#    'RENDIMIENTO\nR',
#    'COSTO\nD=CxR',
#    'Peso Relativo\nElemento (%)',
#    'CPC\nElemento',
#    'NP / EP /\nND',
#    'VAE (%)',
#    'VAE (%)\nElemento'],
#   ['Herramienta Menor 5% de M.O.\n10,39',
#    '2,429%',
#    '4299217233',
#    'EP',
#    '100,00%',
#    '2,429%'],
#   ['NIVEL',
#    '1,00',
#    '3,80',
#    '3,80',
#    '13,670',
#    '51,95',
#    '12,145%',
#    '482120043',
#    'NP',
#    '0,00%',
#    '0,000%'],
#   ['ESTACION TOTAL',
#    '1,00',
#    '8,00',
#    '8,00',
#    '13,670',
#    '109,36',
#    '25,567%',
#    '482120041',
#    'NP',
#    '0,00%',
#    '0,000%'],
#   ['171,70'],
#   ['MANO DE OBRA\nDESCRIPCION',
#    'CANTIDAD\nA',
#    'JORNAL/HR\nB',
#    'COSTO HORA\nC=AxB',
#    'RENDIMIENTO\nR',
#    'COSTO\nD=CxR',
#    'Peso Relativo\nElemento (%)',
#    'CPC\nElemento',
#    'NP / EP /\nND',
#    'VAE (%)',
#    'VAE (%)\nElemento'],
#   ['PEON\nEO E2',
#    '1,00',
#    '3,62',
#    '3,62',
#    '13,670',
#    '49,49',
#    '11,570%',
#    '546220011',
#    'EP',
#    '100,00%',
#    '11,570%'],
#   ['CADENERO\nEO D2',
#    '2,00',
#    '3,66',
#    '7,32',
#    '13,670',
#    '100,06',
#    '23,393%',
#    '546220011',
#    'EP',
#    '100,00%',
#    '23,393%'],
#   ['TOPOGRAFO 2\nEO C1',
#    '1,00',
#    '4,06',
#    '4,06',
#    '13,670',
#    '55,50',
#    '12,975%',
#    '546220011',
#    'EP',
#    '100,00%',
#    '12,975%'],
#   ['MAESTRO DE OBRA\nEO C1',
#    '0,05',
#    '4,06',
#    '0,20',
#    '13,670',
#    '2,73',
#    '0,638%',
#    '546220011',
#    'EP',
#    '100,00%',
#    '0,638%'],
#   ['207,78'],
#   ['MATERIALES\nDESCRIPCION',
#    'UNIDAD',
#    'CANTIDAD\nA',
#    'PRECIO UNIT.\nB',
#    'COSTO\nC=AxB',
#    'Peso Relativo\nElemento (%)',
#    'CPC\nElemento',
#    'NP / EP /\nND',
#    'VAE (%)',
#    'VAE (%)\nElemento'],
#   ['ESTACAS',
#    'ML',
#    '22,000',
#    '1,00',
#    '22,00',
#    '5,143%',
#    '316000311',
#    'EP',
#    '100,00%',
#    '5,143%'],
#   ['PINTURA ESMALTE',
#    'GLN',
#    '1,000',
#    '15,00',
#    '15,00',
#    '3,507%',
#    '351100111',
#    'EP',
#    '100,00%',
#    '3,507%'],
#   ['CLAVOS PARA MADERA',
#    'KG',
#    '1,000',
#    '1,29',
#    '1,29',
#    '0,302%',
#    '429993125',
#    'ND',
#    '40,00%',
#    '0,121%'],
#   ['CAL',
#    'KG',
#    '24,920',
#    '0,40',
#    '9,97',
#    '2,331%',
#    '374400011',
#    'EP',
#    '100,00%',
#    '2,331%'],
#   ['48,26'],
#   ['TRANSPORTE\nDESCRIPCION',
#    'UNIDAD',
#    'CANTIDAD\nA',
#    'TARIFA\nB',
#    'COSTO\nC=AxB',
#    'Peso Relativo\nElemento (%)',
#    'CPC\nElemento',
#    'NP / EP /\nND',
#    'VAE (%)',
#    'VAE (%)\nElemento'],
#   ['0,00'],
#   ['TOTAL COSTO DIRECTO (M+N+O+P)', '427,74', '100,00%'],
#   ['INDIRECTOS (%)\n20,00%', '85,55'],
#   ['UTILIDAD (%)\n0,00%', '0,00'],
#   ['COSTO TOTAL DEL RUBRO', '513,29'],
#   ['VALOR UNITARIO', '513,29']],
#  [['EQUIPO\nDESCRIPCION\n302468641',
#    'CANTIDAD\nA',
#    'TARIFA\nB',
#    'COSTO HORA\nC=AxB',
#    'RENDIMIENTO\nR',
#    'COSTO\nD=CxR',
#    'Peso Relativo\nElemento (%)',
#    'CPC\nElemento',
#    'NP / EP /\nND',
#    'VAE (%)',
#    'VAE (%)\nElemento'],
#   ['Herramienta Menor 5% de M.O.\n0,04',
#    '1,709%',
#    '4299217233',
#    'EP',
#    '100,00%',
#    '1,709%'],
#   ['RETROEXCAVADORA',
#    '1,00',
#    '25,00',
#    '25,00',
#    '0,062',
#    '1,55',
#    '66,239%',
#    '444260012',
#    'NP',
#    '0,00%',
#    '0,000%'],
#   ['1,59'],
#   ['MANO DE OBRA\nDESCRIPCION',
#    'CANTIDAD\nA',
#    'JORNAL/HR\nB',
#    'COSTO HORA\nC=AxB',
#    'RENDIMIENTO\nR',
#    'COSTO\nD=CxR',
#    'Peso Relativo\nElemento (%)',
#    'CPC\nElemento',
#    'NP / EP /\nND',
#    'VAE (%)',
#    'VAE (%)\nElemento'],
#   ['MAESTRO DE OBRA\nEO C1',
#    '0,22',
#    '4,06',
#    '0,89',
#    '0,062',
#    '0,06',
#    '2,564%',
#    '546220011',
#    'EP',
#    '100,00%',
#    '2,564%'],
#   ['PEON\nEO E2',
#    '1,00',
#    '3,62',
#    '3,62',
#    '0,062',
#    '0,22',
#    '9,402%',
#    '546220011',
#    'EP',
#    '100,00%',
#    '9,402%'],
#   ['OP. RETROEXCAVADORA\nOP C1',
#    '1,00',
#    '4,06',
#    '4,06',
#    '0,062',
#    '0,25',
#    '10,684%',
#    '546220011',
#    'EP',
#    '100,00%',
#    '10,684%'],
#   ['AYUDANTE\nEO E2',
#    '1,00',
#    '3,62',
#    '3,62',
#    '0,062',
#    '0,22',
#    '9,402%',
#    '546220011',
#    'EP',
#    '100,00%',
#    '9,402%'],
#   ['0,75'],
#   ['MATERIALES\nDESCRIPCION',
#    'UNIDAD',
#    'CANTIDAD\nA',
#    'PRECIO UNIT.\nB',
#    'COSTO\nC=AxB',
#    'Peso Relativo\nElemento (%)',
#    'CPC\nElemento',
#    'NP / EP /\nND',
#    'VAE (%)',
#    'VAE (%)\nElemento'],
#   ['0,00'],
#   ['TRANSPORTE\nDESCRIPCION',
#    'UNIDAD',
#    'CANTIDAD\nA',
#    'TARIFA\nB',
#    'COSTO\nC=AxB',
#    'Peso Relativo\nElemento (%)',
#    'CPC\nElemento',
#    'NP / EP /\nND',
#    'VAE (%)',
#    'VAE (%)\nElemento'],
#   ['0,00'],
#   ['TOTAL COSTO DIRECTO (M+N+O+P)', '2,34', '100,00%'],
#   ['INDIRECTOS (%)\n20,00%', '0,47'],
#   ['UTILIDAD (%)\n0,00%', '0,00'],
#   ['COSTO TOTAL DEL RUBRO', '2,81'],
#   ['VALOR UNITARIO', '2,81']]]

# %%
import pandas as pd
df = pd.concat([pd.DataFrame(sublist) for sublist in dl], ignore_index=True)

# %%
df
# Out:
#                                      0            1             2   \
# 0        EQUIPO\nDESCRIPCION\n302468641  CANTIDAD\nA     TARIFA\nB
# 1   Herramienta Menor 5% de M.O.\n10,39       2,429%    4299217233
# 2                                 NIVEL         1,00          3,80
# 3                        ESTACION TOTAL         1,00          8,00
# 4                                171,70         None          None
# 5             MANO DE OBRA\nDESCRIPCION  CANTIDAD\nA  JORNAL/HR\nB
# 6                           PEON\nEO E2         1,00          3,62
# 7                       CADENERO\nEO D2         2,00          3,66
# 8                    TOPOGRAFO 2\nEO C1         1,00          4,06
# 9                MAESTRO DE OBRA\nEO C1         0,05          4,06
# 10                               207,78         None          None
# 11              MATERIALES\nDESCRIPCION       UNIDAD   CANTIDAD\nA
# 12                              ESTACAS           ML        22,000
# 13                      PINTURA ESMALTE          GLN         1,000
# 14                   CLAVOS PARA MADERA           KG         1,000
# 15                                  CAL           KG        24,920
# 16                                48,26         None          None
# 17              TRANSPORTE\nDESCRIPCION       UNIDAD   CANTIDAD\nA
# 18                                 0,00         None          None
# 19        TOTAL COSTO DIRECTO (M+N+O+P)       427,74       100,00%
# 20               INDIRECTOS (%)\n20,00%        85,55          None
# 21                  UTILIDAD (%)\n0,00%         0,00          None
# 22                COSTO TOTAL DEL RUBRO       513,29          None
# 23                       VALOR UNITARIO       513,29          None
# 24       EQUIPO\nDESCRIPCION\n302468641  CANTIDAD\nA     TARIFA\nB
# 25   Herramienta Menor 5% de M.O.\n0,04       1,709%    4299217233
# 26                      RETROEXCAVADORA         1,00         25,00
# 27                                 1,59         None          None
# 28            MANO DE OBRA\nDESCRIPCION  CANTIDAD\nA  JORNAL/HR\nB
# 29               MAESTRO DE OBRA\nEO C1         0,22          4,06
# 30                          PEON\nEO E2         1,00          3,62
# 31           OP. RETROEXCAVADORA\nOP C1         1,00          4,06
# 32                      AYUDANTE\nEO E2         1,00          3,62
# 33                                 0,75         None          None
# 34              MATERIALES\nDESCRIPCION       UNIDAD   CANTIDAD\nA
# 35                                 0,00         None          None
# 36              TRANSPORTE\nDESCRIPCION       UNIDAD   CANTIDAD\nA
# 37                                 0,00         None          None
# 38        TOTAL COSTO DIRECTO (M+N+O+P)         2,34       100,00%
# 39               INDIRECTOS (%)\n20,00%         0,47          None
# 40                  UTILIDAD (%)\n0,00%         0,00          None
# 41                COSTO TOTAL DEL RUBRO         2,81          None
# 42                       VALOR UNITARIO         2,81          None
#
#                    3               4                            5   \
# 0   COSTO HORA\nC=AxB  RENDIMIENTO\nR                 COSTO\nD=CxR
# 1                  EP         100,00%                       2,429%
# 2                3,80          13,670                        51,95
# 3                8,00          13,670                       109,36
# 4                None            None                         None
# 5   COSTO HORA\nC=AxB  RENDIMIENTO\nR                 COSTO\nD=CxR
# 6                3,62          13,670                        49,49
# 7                7,32          13,670                       100,06
# 8                4,06          13,670                        55,50
# 9                0,20          13,670                         2,73
# 10               None            None                         None
# 11    PRECIO UNIT.\nB    COSTO\nC=AxB  Peso Relativo\nElemento (%)
# 12               1,00           22,00                       5,143%
# 13              15,00           15,00                       3,507%
# 14               1,29            1,29                       0,302%
# 15               0,40            9,97                       2,331%
# 16               None            None                         None
# 17          TARIFA\nB    COSTO\nC=AxB  Peso Relativo\nElemento (%)
# 18               None            None                         None
# 19               None            None                         None
# 20               None            None                         None
# 21               None            None                         None
# 22               None            None                         None
# 23               None            None                         None
# 24  COSTO HORA\nC=AxB  RENDIMIENTO\nR                 COSTO\nD=CxR
# 25                 EP         100,00%                       1,709%
# 26              25,00           0,062                         1,55
# 27               None            None                         None
# 28  COSTO HORA\nC=AxB  RENDIMIENTO\nR                 COSTO\nD=CxR
# 29               0,89           0,062                         0,06
# 30               3,62           0,062                         0,22
# 31               4,06           0,062                         0,25
# 32               3,62           0,062                         0,22
# 33               None            None                         None
# 34    PRECIO UNIT.\nB    COSTO\nC=AxB  Peso Relativo\nElemento (%)
# 35               None            None                         None
# 36          TARIFA\nB    COSTO\nC=AxB  Peso Relativo\nElemento (%)
# 37               None            None                         None
# 38               None            None                         None
# 39               None            None                         None
# 40               None            None                         None
# 41               None            None                         None
# 42               None            None                         None
#
#                              6              7              8   \
# 0   Peso Relativo\nElemento (%)  CPC\nElemento  NP / EP /\nND
# 1                          None           None           None
# 2                       12,145%      482120043             NP
# 3                       25,567%      482120041             NP
# 4                          None           None           None
# 5   Peso Relativo\nElemento (%)  CPC\nElemento  NP / EP /\nND
# 6                       11,570%      546220011             EP
# 7                       23,393%      546220011             EP
# 8                       12,975%      546220011             EP
# 9                        0,638%      546220011             EP
# 10                         None           None           None
# 11                CPC\nElemento  NP / EP /\nND        VAE (%)
# 12                    316000311             EP        100,00%
# 13                    351100111             EP        100,00%
# 14                    429993125             ND         40,00%
# 15                    374400011             EP        100,00%
# 16                         None           None           None
# 17                CPC\nElemento  NP / EP /\nND        VAE (%)
# 18                         None           None           None
# 19                         None           None           None
# 20                         None           None           None
# 21                         None           None           None
# 22                         None           None           None
# 23                         None           None           None
# 24  Peso Relativo\nElemento (%)  CPC\nElemento  NP / EP /\nND
# 25                         None           None           None
# 26                      66,239%      444260012             NP
# 27                         None           None           None
# 28  Peso Relativo\nElemento (%)  CPC\nElemento  NP / EP /\nND
# 29                       2,564%      546220011             EP
# 30                       9,402%      546220011             EP
# 31                      10,684%      546220011             EP
# 32                       9,402%      546220011             EP
# 33                         None           None           None
# 34                CPC\nElemento  NP / EP /\nND        VAE (%)
# 35                         None           None           None
# 36                CPC\nElemento  NP / EP /\nND        VAE (%)
# 37                         None           None           None
# 38                         None           None           None
# 39                         None           None           None
# 40                         None           None           None
# 41                         None           None           None
# 42                         None           None           None
#
#                    9                  10
# 0             VAE (%)  VAE (%)\nElemento
# 1                None               None
# 2               0,00%             0,000%
# 3               0,00%             0,000%
# 4                None               None
# 5             VAE (%)  VAE (%)\nElemento
# 6             100,00%            11,570%
# 7             100,00%            23,393%
# 8             100,00%            12,975%
# 9             100,00%             0,638%
# 10               None               None
# 11  VAE (%)\nElemento               None
# 12             5,143%               None
# 13             3,507%               None
# 14             0,121%               None
# 15             2,331%               None
# 16               None               None
# 17  VAE (%)\nElemento               None
# 18               None               None
# 19               None               None
# 20               None               None
# 21               None               None
# 22               None               None
# 23               None               None
# 24            VAE (%)  VAE (%)\nElemento
# 25               None               None
# 26              0,00%             0,000%
# 27               None               None
# 28            VAE (%)  VAE (%)\nElemento
# 29            100,00%             2,564%
# 30            100,00%             9,402%
# 31            100,00%            10,684%
# 32            100,00%             9,402%
# 33               None               None
# 34  VAE (%)\nElemento               None
# 35               None               None
# 36  VAE (%)\nElemento               None
# 37               None               None
# 38               None               None
# 39               None               None
# 40               None               None
# 41               None               None
# 42               None               None
